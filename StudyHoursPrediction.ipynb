# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data={
    "hours":[1,2,5,4,3],
     "marks":[40,50,90,70,60]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    hours  marks
# 0      1     40
# 1      2     50
# 2      5     90
# 3      4     70
# 4      3     60

# %%
X=df[["hours"]]
Y=df["marks"]

# %%
model=LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
test = pd.DataFrame({"hours":[6]})
model.predict(test)
# Out:
# array([98.])

# %%
plt.scatter(X,y)
plt.plot(X, model.predict(X))
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.show()
