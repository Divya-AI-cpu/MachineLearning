# %%
import pandas as pd

# %%
data = {
    "Name": ["A", "B", "C", "D"],
    "Marks": [85, 90, 78, 92],
    "Hours": [5, 6, 4, 7]
}

df = pd.DataFrame(data)

df
# Out:
#   Name  Marks  Hours
# 0    A     85      5
# 1    B     90      6
# 2    C     78      4
# 3    D     92      7

# %%
df.head()
# Out:
#   Name  Marks  Hours
# 0    A     85      5
# 1    B     90      6
# 2    C     78      4
# 3    D     92      7

# %%
df.head(2)
# Out:
#   Name  Marks  Hours
# 0    A     85      5
# 1    B     90      6

# %%
df.tail(3)
# Out:
#   Name  Marks  Hours
# 1    B     90      6
# 2    C     78      4
# 3    D     92      7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Marks   4 non-null      int64
#  2   Hours   4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#            Marks     Hours
# count   4.000000  4.000000
# mean   86.250000  5.500000
# std     6.238322  1.290994
# min    78.000000  4.000000
# 25%    83.250000  4.750000
# 50%    87.500000  5.500000
# 75%    90.500000  6.250000
# max    92.000000  7.000000

# %%
df["Marks"]
# Out:
# 0    85
# 1    90
# 2    78
# 3    92
# Name: Marks, dtype: int64

# %%
df[["Name","Marks"]]
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78
# 3    D     92

# %%
df.iloc[0]
# Out:
# Name      A
# Marks    85
# Hours     5
# Name: 0, dtype: object
